# %% [markdown]
# <h1>Document Similarity using LSI</h1>

# %% [markdown]
# <h4>In this assignment we’re going to practice document similarity. Here’s
# what you need to do:</h4>
# <ol>
# <li>From Wikipedia’s List of musicians page (https://en.wikipedia.org/wiki/Lists_of_musicians), pick five lists of
# musicians (e.g., List of big band musicians). You can pick any five
# you like but make sure that the list has the words “musicians” in
# it and that the list has at least 30 musicians listed
# <li>Collect the urls of all the musicians on those five pages and place them in a list
# <li>Grab the content of each musician in the list and place them in a list (of documents)
# <li>Build an LSI model using this data. This is your "reference" data set
# <li>Now grab another list of musicians from wikipedia and create a new list of documents using the detail from each musicians page. This is your "musician" data set
# <li>For each musician in the new list, find the musician in the reference data set that is the closest in similarity.
# <li>Print a table that contains each musician from the musician data set and the most similar musician from the reference data set
# </ol>
# <h4>Use the code below to build your solution

# %% [markdown]
# <p><span style="color:blue">get_musicians</span>: A function that, given a "list of musicians" url, returns a list containing the names of the musicians and the urls for their wikipedia pages
# <p>non_musician_finder tries its best to remove links that are not musician links from the page (not perfect, but good enough!)

# %%
from gensim.similarities.docsim import Similarity
from gensim import corpora, models, similarities
from gensim import corpora, models, similarities
from collections import OrderedDict
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.corpus import PlaintextCorpusReader
from nltk import sent_tokenize,word_tokenize 
from nltk.corpus import gutenberg
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/vriddhimisra/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def get_musicians(url):
    from bs4 import BeautifulSoup
    import requests
    page_soup = BeautifulSoup(requests.get(url).content,'lxml')
    li_tags = page_soup.find_all('li')
    all_musicians = list()
    for tag in li_tags:
        if tag.get('id'):
            continue

        try:
            tag.find('sup',class_="reference")
            link = tag.find('a').get('href')
            name = tag.find('a').get_text()
            if "/wiki/" in link and non_musician_finder(link):
                all_musicians.append((name,"https://en.wikipedia.org" + link))
        except:
            pass
    return all_musicians

def non_musician_finder(link):
    non_musician_words = ['Category','Template','Portal','List','File','Template','Special','Main','Help','User']
    for word in non_musician_words:
        if word in link:
            return False
    return True

# %% [markdown]
# <h4>testing the function</h4>
# <li>Note that Wikipedia does not have a standard for its page design so this code may not work with every list

# %%
url = "https://en.wikipedia.org/wiki/List_of_alternative_country_musicians"
get_musicians(url)
# Out:
# [('16 Horsepower', 'https://en.wikipedia.org/wiki/16_Horsepower'),
#  ('Ryan Adams', 'https://en.wikipedia.org/wiki/Ryan_Adams'),
#  ('Jill Andrews', 'https://en.wikipedia.org/wiki/Jill_Andrews'),
#  ('The Autumn Defense', 'https://en.wikipedia.org/wiki/The_Autumn_Defense'),
#  ('Backyard Tire Fire', 'https://en.wikipedia.org/wiki/Backyard_Tire_Fire'),
#  ('Del Barber', 'https://en.wikipedia.org/wiki/Del_Barber'),
#  ('Eef Barzelay', 'https://en.wikipedia.org/wiki/Eef_Barzelay'),
#  ("Bear's Den", 'https://en.wikipedia.org/wiki/Bear%27s_Den_(band)'),
#  ('Rico Bell', 'https://en.wikipedia.org/wiki/Rico_Bell'),
#  ('Blitzen Trapper', 'https://en.wikipedia.org/wiki/Blitzen_Trapper'),
#  ('Blue Rodeo', 'https://en.wikipedia.org/wiki/Blue_Rodeo'),
#  ('Bosque Brown', 'https://en.wikipedia.org/wiki/Bosque_Brown'),
#  ('The Bottle Rockets', 'https://en.wikipedia.org/wiki/The_Bottle_Rockets'),
#  ('BR549', 'https://en.wikipedia.org/wiki/BR549'),
#  ('Jim Bryson', 'https://en.wikipedia.org/wiki/Jim_Bryson'),
#  ('Richard Buckner',
#   'https://en.wikipedia.org/wiki/Richard_Buckner_(musician)'),
#  ('Caitlin Cary', 'https://en.wikipedia.org/wiki/Caitlin_Cary'),
#  ('Neko Case', 'https://en.wikipedia.org/wiki/Neko_Case'),
#  ('Cross Canadian Ragweed',
#   'https://en.wikipedia.org/wiki/Cross_Canadian_Ragweed'),
#  ('The Deep Dark Woods', 'https://en.wikipedia.org/wiki/The_Deep_Dark_Woods'),
#  ('The Devil Makes Three',
#   'https://en.wikipedia.org/wiki/The_Devil_Makes_Three_(band)'),
#  ('Drive-By Truckers', 'https://en.wikipedia.org/wiki/Drive-By_Truckers'),
#  ('Tim Easton', 'https://en.wikipedia.org/wiki/Tim_Easton'),
#  ('Carrie Elkin', 'https://en.wikipedia.org/wiki/Carrie_Elkin'),
#  ('Elliott Brood', 'https://en.wikipedia.org/wiki/Elliott_Brood'),
#  ('Alejandro Escovedo', 'https://en.wikipedia.org/wiki/Alejandro_Escovedo'),
#  ('Jay Farrar', 'https://en.wikipedia.org/wiki/Jay_Farrar'),
#  ('Fifth on the Floor', 'https://en.wikipedia.org/wiki/Fifth_on_the_Floor'),
#  ('Rosie Flores', 'https://en.wikipedia.org/wiki/Rosie_Flores'),
#  ('Freakwater', 'https://en.wikipedia.org/wiki/Freakwater'),
#  ('Robbie Fulks', 'https://en.wikipedia.org/wiki/Robbie_Fulks'),
#  ('Mary Gauthier', 'https://en.wikipedia.org/wiki/Mary_Gauthier'),
#  ('Giant Sand', 'https://en.wikipedia.org/wiki/Giant_Sand'),
#  ('Golden Smog', 'https://en.wikipedia.org/wiki/Golden_Smog'),
#  ('The Gourds', 'https://en.wikipedia.org/wiki/The_Gourds'),
#  ('Green on Red', 'https://en.wikipedia.org/wiki/Green_on_Red'),
#  ('Grievous Angels', 'https://en.wikipedia.org/wiki/Grievous_Angels'),
#  ('The Guthries', 'https://en.wikipedia.org/wiki/The_Guthries'),
#  ('Sarah Lee Guthrie',
#   'https://en.wikipedia.org/wiki/Sarah_Lee_Guthrie_%26_Johnny_Irion'),
#  ('Hacienda Brothers', 'https://en.wikipedia.org/wiki/Hacienda_Brothers'),
#  ('Wayne Hancock', 'https://en.wikipedia.org/wiki/Wayne_Hancock'),
#  ('The Handsome Family', 'https://en.wikipedia.org/wiki/The_Handsome_Family'),
#  ('Thomas Hansen', 'https://en.wikipedia.org/wiki/Thomas_Hansen_(musician)'),
#  ('Hazeldine', 'https://en.wikipedia.org/wiki/Hazeldine_(band)'),
#  ('Jesse Sykes & the Sweet Hereafter',
#   'https://en.wikipedia.org/wiki/Jesse_Sykes'),
#  ('Tarnation', 'https://en.wikipedia.org/wiki/Tarnation_(band)'),
#  ("Three O'Clock Train",
#   'https://en.wikipedia.org/wiki/Three_O%27Clock_Train'),
#  ('Tres Chicas', 'https://en.wikipedia.org/wiki/Tres_Chicas'),
#  ('Jeff Tweedy', 'https://en.wikipedia.org/wiki/Jeff_Tweedy'),
#  ('Two Cow Garage', 'https://en.wikipedia.org/wiki/Two_Cow_Garage'),
#  ('Ugly Casanova', 'https://en.wikipedia.org/wiki/Ugly_Casanova'),
#  ('Uncle Tupelo', 'https://en.wikipedia.org/wiki/Uncle_Tupelo'),
#  ('Suzie Ungerleider', 'https://en.wikipedia.org/wiki/Suzie_Ungerleider'),
#  ('Townes Van Zandt', 'https://en.wikipedia.org/wiki/Townes_Van_Zandt'),
#  ('The Waco Brothers', 'https://en.wikipedia.org/wiki/The_Waco_Brothers'),
#  ('Water Liars', 'https://en.wikipedia.org/wiki/Water_Liars'),
#  ('Whiskeytown', 'https://en.wikipedia.org/wiki/Whiskeytown'),
#  ('Wilco', 'https://en.wikipedia.org/wiki/Wilco'),
#  ('Kelly Willis', 'https://en.wikipedia.org/wiki/Kelly_Willis'),
#  ('Larkin, Colin', 'https://en.wikipedia.org/wiki/Colin_Larkin_(writer)')]

# %% [markdown]
# <h4>get_musician_text(url): returns the page text of the wikipedia page associated with a musician</h4>
# <li>Since we're not sure if this will always work, we use a try ... except to catch exceptions
# <li>If it doesn't work, the function returns None
# <li>We will need to delete this (musician, url) pair from our musicians list

# %%
def get_musician_text(url):
    from bs4 import BeautifulSoup
    import requests
    all_text = ''
    try:
        page_soup = BeautifulSoup(requests.get(url).content,'lxml')
        for p_tag in page_soup.find_all('p'):
            all_text += p_tag.get_text()
    except:
        return None
    return all_text

# %% [markdown]
# <h4>testing get_musician_text</h4>

# %%
url = "https://en.wikipedia.org/wiki/Jim_Morrison"
get_musician_text(url)
# Out:
# '\nJames Douglas Morrison (December 8, 1943 – July 3, 1971) was an American singer, poet and songwriter who was the lead vocalist of the rock band the Doors. Due to his wild personality, poetic lyrics, distinctive voice, unpredictable and erratic performances, and the dramatic circumstances surrounding his life and early death, Morrison is regarded by music critics and fans as one of the most influential frontmen in rock history. Since his death, Morrison\'s fame has endured as one of popular culture\'s top rebellious and oft-displayed icons, representing the generation gap and youth counterculture.[3]\nTogether with pianist Ray Manzarek, Morrison founded the Doors in 1965 in Venice, California. The group spent two years in obscurity until shooting to prominence with their number-one single in the United States, "Light My Fire", taken from their self-titled debut album. Morrison recorded a total of six studio albums with the Doors, all of which sold well and received critical acclaim. He was well known for improvising spoken word poetry passages while the band played live. Manzarek said Morrison "embodied hippie counterculture rebellion".[4]\nMorrison developed an alcohol dependency throughout the band\'s career, which at times affected his performances on stage.[5][6][7] On July 3, 1971, Morrison died unexpectedly in Paris at the age of 27, amid several conflicting witness reports. His premature death is often linked with the 27 Club. Since no autopsy was performed, the cause of Morrison\'s death remains disputed.[8]\nAlthough the Doors recorded two more albums after Morrison died, his death severely affected the band\'s fortunes, and they split up two years later. In 1993, Morrison was inducted into the Rock and Roll Hall of Fame along with the other Doors members.[9] In 2011, a Rolling Stone readers\' pick placed Morrison in fifth position on the magazine\'s "Best Lead Singers of All Time",[10] and in another Rolling Stone list of "The 100 Greatest Singers of All Time", he was ranked 47th.[11] He was also ranked the 22nd greatest singer in rock by Classic Rock magazine.[12]\nJames Douglas Morrison was born on December 8, 1943 in Melbourne, Florida, to Clara Virginia (née Clarke; 1919–2005) and Lt.(j.g.) George Stephen Morrison (1919–2008), a future rear admiral in the United States Navy.[13] His\xa0ancestors were Scottish, Irish, and English.[14][15] Admiral Morrison commanded U.S. naval forces during the Gulf of Tonkin incident in August 1964, which provided the pretext for the U.S. involvement in the Vietnam War in 1965.[16] Morrison had a younger sister, Anne Robin (born 1947 in Albuquerque, New Mexico), and a younger brother, Andrew Lee Morrison (born 1948 in Los Altos, California).[17]\nIn 1947, when he was three to four years old, Morrison allegedly witnessed a car accident in the desert, during which a truck overturned and some Native Americans were lying injured on the side of the road. He referred to this incident in the Doors\' song "Peace Frog" on their 1970 album Morrison Hotel, as well as in the spoken word performances "Dawn\'s Highway" and "Ghost Song" on the posthumous 1978 album An American Prayer.[18] Morrison believed this incident to be the most formative event of his life,[19] and made repeated references to it in the imagery in his songs, poems, and interviews.[20] Morrison believed the spirits or the ghosts of those "dead Indians leapt into [his] soul," and that he was "like a sponge, ready to sit there and absorb it."[21]\nMorrison\'s family does not recall this traffic incident happening in the way he told it. According to the Morrison biography No One Here Gets Out Alive, his family did drive past a car accident on an Indian reservation when he was a child, and he was very upset by it.[22] The book The Doors, written by the surviving members of the band, explains how different Morrison\'s account of the incident was from that of his father, who is quoted as saying, "We went by several Indians. It d ...

# %% [markdown]
# <p><span style="color:blue">get_all_musicians</span>: A function that, given a list of genres, returns a list containing the names of the musicians and the urls for their wikipedia pages associated with that list of genres
# <p>The function should return a list of (name,url) pairs for all the musicians in the list of genres
# <p>You need to:
# <ol>
# <li>iterate through the list of genres
# <li>initialize a list "all_musicians"
# <li>construct a url for the list of musicians (I've done these first three steps for you)
# <li>call get_musicians for that url
# <li>extend all_musicians by what get_musicians returns

# %%
def get_all_musicians(genre_list):
    all_musicians = list()
    for genre in genre_list:
        url = 'https://en.wikipedia.org/wiki/List_of_' + genre
        all_musicians.extend(get_musicians(url))
    
    return all_musicians

# %% [markdown]
# <h4>Example of how to use get_all_musicians</h4>

# %%
genre_list = ['bluegrass_musicians#G','British_blues_musicians','country_blues_musicians','emo_artists']
all_musicians = get_all_musicians(genre_list)

# %%
all_musicians
# Out:
# [('Tom Adams', 'https://en.wikipedia.org/wiki/Tom_Adams_(bluegrass_musician)'),
#  ('Eddie Adcock', 'https://en.wikipedia.org/wiki/Eddie_Adcock'),
#  ('David "Stringbean" Akeman',
#   'https://en.wikipedia.org/wiki/David_%22Stringbean%22_Akeman'),
#  ('technique', 'https://en.wikipedia.org/wiki/Bluegrass_fiddle'),
#  ('Mandolin', 'https://en.wikipedia.org/wiki/Mandolin'),
#  ('resonator', 'https://en.wikipedia.org/wiki/Resonator_mandolin'),
#  ('technique', 'https://en.wikipedia.org/wiki/Bluegrass_mandolin'),
#  ('Blues', 'https://en.wikipedia.org/wiki/Blues'),
#  ('Country music', 'https://en.wikipedia.org/wiki/Country_music'),
#  ('Jazz', 'https://en.wikipedia.org/wiki/Jazz'),
#  ('Old-time music', 'https://en.wikipedia.org/wiki/Old-time_music'),
#  ('Traditional bluegrass',
#   'https://en.wikipedia.org/wiki/Traditional_bluegrass'),
#  ('Czech bluegrass', 'https://en.wikipedia.org/wiki/Czech_bluegrass'),
#  ('High Sierra Music Festival',
#   'https://en.wikipedia.org/wiki/High_Sierra_Music_Festival'),
#  ('Festival of the Bluegrass',
#   'https://en.wikipedia.org/wiki/Festival_of_the_Bluegrass'),
#  ('Merlefest', 'https://en.wikipedia.org/wiki/MerleFest'),
#  ('Podunk Bluegrass Festival',
#   'https://en.wikipedia.org/wiki/Podunk_Bluegrass_Festival'),
#  ('Telluride Bluegrass Festival',
#   'https://en.wikipedia.org/wiki/Telluride_Bluegrass_Festival'),
#  ('Tottenham Bluegrass Festival',
#   'https://en.wikipedia.org/wiki/Tottenham_Bluegrass_Festival'),
#  ('International Bluegrass Music Museum',
#   'https://en.wikipedia.org/wiki/International_Bluegrass_Music_Museum'),
#  ('International Bluegrass Music Association',
#   'https://en.wikipedia.org/wiki/International_Bluegrass_Music_Association'),
#  ('International Bluegrass Music Hall of Fame',
#   'https://en.wikipedia.org/wiki/International_Bluegrass_Music_Hall_of_Fame'),
#  ('Bluegrass Unlimited', 'https://en.wikipedia.org/wiki/Bluegrass_Unlimited'),
#  ('Central Canadian Bluegrass Awards',
#   'https://en.wikipedia.org/wiki/Central_Canadian_Bluegrass_Awards'),
#  ('International Bluegrass Music Awards',
#   'https://en.wikipedia.org/wiki/International_Bluegrass_Music_Awards'),
#  ('Ian A. Anderson', 'https://en.wikipedia.org/wiki/Ian_A._Anderson'),
#  ('Elles Bailey', 'https://en.wikipedia.org/wiki/Elles_Bailey'),
#  ('Ginger Baker', 'https://en.wikipedia.org/wiki/Ginger_Baker'),
#  ('Long John Baldry', 'https://en.wikipedia.org/wiki/Long_John_Baldry'),
#  ('Chris Barber', 'https://en.wikipedia.org/wiki/Chris_Barber'),
#  ('Norman Beaker', 'https://en.wikipedia.org/wiki/Norman_Beaker'),
#  ('Jeff Beck', 'https://en.wikipedia.org/wiki/Jeff_Beck'),
#  ('Duster Bennett', 'https://en.wikipedia.org/wiki/Duster_Bennett'),
#  ('Graham Bond', 'https://en.wikipedia.org/wiki/Graham_Bond'),
#  ('Marcus Bonfanti', 'https://en.wikipedia.org/wiki/Marcus_Bonfanti'),
#  ('John Bonham', 'https://en.wikipedia.org/wiki/John_Bonham'),
#  ('Geoff Bradford', 'https://en.wikipedia.org/wiki/Geoff_Bradford_(musician)'),
#  ('The Groundhogs', 'https://en.wikipedia.org/wiki/The_Groundhogs'),
#  ('The Hamsters', 'https://en.wikipedia.org/wiki/The_Hamsters'),
#  ('Jeff Beck Group', 'https://en.wikipedia.org/wiki/Jeff_Beck_Group'),
#  ('The Jimi Hendrix Experience',
#   'https://en.wikipedia.org/wiki/The_Jimi_Hendrix_Experience'),
#  ('John Mayall & the Bluesbreakers',
#   'https://en.wikipedia.org/wiki/John_Mayall_%26_the_Bluesbreakers'),
#  ('Juicy Lucy', 'https://en.wikipedia.org/wiki/Juicy_Lucy_(band)'),
#  ('Keef Hartley Band', 'https://en.wikipedia.org/wiki/Keef_Hartley_Band'),
#  ('King King', 'https://en.wikipedia.org/wiki/King_King_(band)'),
#  ('Led Zeppelin', 'https://en.wikipedia.org/wiki/Led_Zeppelin'),
#  ('Love Sculpture', 'https://en.wikipedia.org/wiki/Love_Sculpture'),
#  ('Manfred Mann', 'https://en.wikipedia.org/wiki/Manfred_Mann'),
#  ('Medicine Head', 'https://en.wikipedia.org/wiki/Medicine_Head'),
#  ('The Original Rabbit Foot Spasm Band',
#   'https://en.wikipedia.org/wiki/The_Original_Rabbit_Foot_Spasm_Band'),
#  ('Peter Green Splinter Group',
#   'https://en.wikipedia.org/wiki/Peter_Green_Splinter_Group'),
#  ('The Poets', 'https://en.wikipedia.org/wiki/The_Poets'),
#  ('The Pretty Things', 'https://en.wikipedia.org/wiki/The_Pretty_Things'),
#  ('The Rolling Stones', 'https://en.wikipedia.org/wiki/The_Rolling_Stones'),
#  ('Savoy Brown', 'https://en.wikipedia.org/wiki/Savoy_Brown'),
#  ('Spencer Davis Group', 'https://en.wikipedia.org/wiki/Spencer_Davis'),
#  ('Starlite Campbell Band',
#   'https://en.wikipedia.org/wiki/Starlite_Campbell_Band'),
#  ('Steamhammer', 'https://en.wikipedia.org/wiki/Steamhammer_(band)'),
#  ('The Steampacket', 'https://en.wikipedia.org/wiki/The_Steampacket'),
#  ('Taste', 'https://en.wikipedia.org/wiki/Taste_(Irish_band)'),
#  ('Ten Years After', 'https://en.wikipedia.org/wiki/Ten_Years_After'),
#  ('Them', 'https://en.wikipedia.org/wiki/Them_(band)'),
#  ('Tramp', 'https://en.wikipedia.org/wiki/Tramp_(band)'),
#  ('Twice as Much', 'https://en.wikipedia.org/wiki/Twice_as_Much'),
#  ('The Yardbirds', 'https://en.wikipedia.org/wiki/The_Yardbirds'),
#  ('When Rivers Meet', 'https://en.wikipedia.org/wiki/When_Rivers_Meet'),
#  ('Whitesnake', 'https://en.wikipedia.org/wiki/Whitesnake'),
#  ('Wishbone Ash', 'https://en.wikipedia.org/wiki/Wishbone_Ash'),
#  ('Blues ballad', 'https://en.wikipedia.org/wiki/Blues_ballad'),
#  ('Blue note', 'https://en.wikipedia.org/wiki/Blue_note'),
#  ('Blues scale', 'https://en.wikipedia.org/wiki/Blues_scale'),
#  ('Call and response',
#   'https://en.wikipedia.org/wiki/Call_and_response_(music)'),
#  ('Eight-bar blues', 'https://en.wikipedia.org/wiki/Eight-bar_blues'),
#  ('Musical improvisation',
#   'https://en.wikipedia.org/wiki/Musical_improvisation'),
#  ('Shuffles', 'https://en.wikipedia.org/wiki/Shuffle_note'),
#  ('Traditional blues verses',
#   'https://en.wikipedia.org/wiki/Traditional_blues_verses'),
#  ('Twelve-bar blues', 'https://en.wikipedia.org/wiki/Twelve-bar_blues'),
#  ('Walking bass', 'https://en.wikipedia.org/wiki/Walking_bass'),
#  ('Origins', 'https://en.wikipedia.org/wiki/Origins_of_the_blues'),
#  ('Field hollers', 'https://en.wikipedia.org/wiki/Field_holler'),
#  ('Spirituals', 'https://en.wikipedia.org/wiki/Spiritual_(music)'),
#  ('Work songs',
#   'https://en.wikipedia.org/wiki/Work_song#African-American_work_songs'),
#  ('American folk music', 'https://en.wikipedia.org/wiki/American_folk_music'),
#  ('African blues', 'https://en.wikipedia.org/wiki/African_blues'),
#  ('Anatolian blues', 'https://en.wikipedia.org/wiki/Anatolian_blues'),
#  ('British blues', 'https://en.wikipedia.org/wiki/British_blues'),
#  ('Canadian blues', 'https://en.wikipedia.org/wiki/Canadian_blues'),
#  ('Chicago blues', 'https://en.wikipedia.org/wiki/Chicago_blues'),
#  ('Delta blues', 'https://en.wikipedia.org/wiki/Delta_blues'),
#  ('Hill country blues', 'https://en.wikipedia.org/wiki/Hill_country_blues'),
#  ('Indian blues', 'https://en.wikipedia.org/wiki/Indian_blues'),
#  ('Louisiana blues', 'https://en.wikipedia.org/wiki/Louisiana_blues'),
#  ('New Orleans blues', 'https://en.wikipedia.org/wiki/New_Orleans_blues'),
#  ('Swamp blues', 'https://en.wikipedia.org/wiki/Swamp_blues'),
#  ('Memphis blues', 'https://en.wikipedia.org/wiki/Memphis_blues'),
#  ('Piedmont blues', 'https://en.wikipedia.org/wiki/Piedmont_blues'),
#  ('Texas blues', 'https://en.wikipedia.org/wiki/Texas_blues'),
#  ('West Coast blues', 'https://en.wikipedia.org/wiki/West_Coast_blues'),
#  ('Boogie-woogie', 'https://en.wikipedia.org/wiki/Boogie-woogie'),
#  ('Classic female blues',
#   'https://en.wikipedia.org/wiki/Classic_female_blues'),
#  ('Country blues', 'https://en.wikipedia.org/wiki/Country_blues'),
#  ('Dirty blues', 'https://en.wikipedia.org/wiki/Dirty_blues'),
#  ('Electric blues', 'https://en.wikipedia.org/wiki/Electric_blues'),
#  ('Fife and drum blues', 'https://en.wikipedia.org/wiki/Fife_and_drum_blues'),
#  ('Hokum', 'https://en.wikipedia.org/wiki/Hokum'),
#  ('Jug band', 'https://en.wikipedia.org/wiki/Jug_band'),
#  ('Rhythm and blues', 'https://en.wikipedia.org/wiki/Rhythm_and_blues'),
#  ('Blues rock', 'https://en.wikipedia.org/wiki/Blues_rock'),
#  ('Gospel blues', 'https://en.wikipedia.org/wiki/Gospel_blues'),
#  ('Jump blues', 'https://en.wikipedia.org/wiki/Jump_blues'),
#  ('Southern rock', 'https://en.wikipedia.org/wiki/Southern_rock'),
#  ('Alger "Texas" Alexander',
#  ('Jesse Fuller', 'https://en.wikipedia.org/wiki/Jesse_Fuller'),
#  ('Terry Garland', 'https://en.wikipedia.org/wiki/Terry_Garland'),
#  ('Jazz Gillum', 'https://en.wikipedia.org/wiki/Jazz_Gillum'),
#  ('Ramon Goose', 'https://en.wikipedia.org/wiki/Ramon_Goose'),
#  ('Coot Grant', 'https://en.wikipedia.org/wiki/Coot_Grant'),
#  ('William Harris', 'https://en.wikipedia.org/wiki/William_Harris_(musician)'),
#  ('Richard "Hacksaw" Harney',
#   'https://en.wikipedia.org/wiki/Richard_%22Hacksaw%22_Harney'),
#  ('Hattie Hart', 'https://en.wikipedia.org/wiki/Hattie_Hart'),
#  ('Buddy Boy Hawkins', 'https://en.wikipedia.org/wiki/Buddy_Boy_Hawkins'),
#  ('Jessie Mae Hemphill', 'https://en.wikipedia.org/wiki/Jessie_Mae_Hemphill'),
#  ("Lightnin' Hopkins", 'https://en.wikipedia.org/wiki/Lightnin%27_Hopkins'),
#  ('Son House', 'https://en.wikipedia.org/wiki/Son_House'),
#  ('Peg Leg Howell', 'https://en.wikipedia.org/wiki/Peg_Leg_Howell'),
#  ('Mississippi John Hurt',
#   'https://en.wikipedia.org/wiki/Mississippi_John_Hurt'),
#  ('Melvin "Lil\' Son" Jackson',
#   'https://en.wikipedia.org/wiki/Melvin_Jackson'),
#  ('Papa Charlie Jackson',
#   'https://en.wikipedia.org/wiki/Papa_Charlie_Jackson'),
#  ('Skip James', 'https://en.wikipedia.org/wiki/Skip_James'),
#  ('Blind Lemon Jefferson',
#   'https://en.wikipedia.org/wiki/Blind_Lemon_Jefferson'),
#  ('Herman E. Johnson', 'https://en.wikipedia.org/wiki/Herman_E._Johnson'),
#  ('Lonnie Johnson', 'https://en.wikipedia.org/wiki/Lonnie_Johnson_(musician)'),
#  ('Robert Johnson', 'https://en.wikipedia.org/wiki/Robert_Johnson_(musician)'),
#  ('Blind Willie Johnson',
#   'https://en.wikipedia.org/wiki/Blind_Willie_Johnson'),
#  ('Richard Johnston',
#   'https://en.wikipedia.org/wiki/Richard_Johnston_(musician)'),
#  ('Tutu Jones', 'https://en.wikipedia.org/wiki/Tutu_Jones'),
#  ('Luke Jordan', 'https://en.wikipedia.org/wiki/Luke_Jordan'),
#  ('Junior Kimbrough', 'https://en.wikipedia.org/wiki/Junior_Kimbrough'),
#  ('Lottie Kimbrough', 'https://en.wikipedia.org/wiki/Lottie_Kimbrough'),
#  ('Lead Belly', 'https://en.wikipedia.org/wiki/Lead_Belly'),
#  ('John Lee', 'https://en.wikipedia.org/wiki/John_Lee_(blues_musician)'),
#  ('Furry Lewis', 'https://en.wikipedia.org/wiki/Furry_Lewis'),
#  ('Noah Lewis', 'https://en.wikipedia.org/wiki/Noah_Lewis'),
#  ('Charley Lincoln', 'https://en.wikipedia.org/wiki/Charley_Lincoln'),
#  ('Mance Lipscomb', 'https://en.wikipedia.org/wiki/Mance_Lipscomb'),
#  ('Robert Lockwood, Jr.',
#  ('Laura Smith', 'https://en.wikipedia.org/wiki/Laura_Smith_(blues_singer)'),
#  ('Victoria Spivey', 'https://en.wikipedia.org/wiki/Victoria_Spivey'),
#  ('Frank Stokes', 'https://en.wikipedia.org/wiki/Frank_Stokes_(musician)'),
#  ('Tampa Red', 'https://en.wikipedia.org/wiki/Tampa_Red'),
#  ('Baby Tate', 'https://en.wikipedia.org/wiki/Baby_Tate_(guitarist)'),
#  ('Sonny Terry', 'https://en.wikipedia.org/wiki/Sonny_Terry'),
#  ('Henry Thomas',
#   'https://en.wikipedia.org/wiki/Henry_Thomas_(blues_musician)'),
#  ("Ramblin' Thomas", 'https://en.wikipedia.org/wiki/Ramblin%27_Thomas'),
#  ('Bessie Tucker', 'https://en.wikipedia.org/wiki/Bessie_Tucker'),
#  ('Sippie Wallace', 'https://en.wikipedia.org/wiki/Sippie_Wallace'),
#  ('Curley Weaver', 'https://en.wikipedia.org/wiki/Curley_Weaver'),
#  ('Boogie Bill Webb', 'https://en.wikipedia.org/wiki/Boogie_Bill_Webb'),
#  ('Peetie Wheatstraw', 'https://en.wikipedia.org/wiki/Peetie_Wheatstraw'),
#  ('Bukka White', 'https://en.wikipedia.org/wiki/Bukka_White'),
#  ('Big Joe Williams', 'https://en.wikipedia.org/wiki/Big_Joe_Williams'),
#  ('Sonny Boy Williamson I',
#   'https://en.wikipedia.org/wiki/Sonny_Boy_Williamson_I'),
#  ('Sonny Boy Williamson II',
#   'https://en.wikipedia.org/wiki/Sonny_Boy_Williamson_II'),
#  ('Jontavious Willis', 'https://en.wikipedia.org/wiki/Jontavious_Willis'),
#  ('Ralph Willis',
#   'https://en.wikipedia.org/wiki/Ralph_Willis_(blues_musician)'),
#  ('Wesley Wilson', 'https://en.wikipedia.org/wiki/Wesley_Wilson'),
#  ('Johnny Winter', 'https://en.wikipedia.org/wiki/Johnny_Winter'),
#  ('The Academy Is...', 'https://en.wikipedia.org/wiki/The_Academy_Is...'),
#  ('Acceptance', 'https://en.wikipedia.org/wiki/Acceptance_(band)'),
#  ('Ace Troubleshooter', 'https://en.wikipedia.org/wiki/Ace_Troubleshooter'),
#  ('AFI', 'https://en.wikipedia.org/wiki/AFI_(band)'),
#  ('Aiden', 'https://en.wikipedia.org/wiki/Aiden'),
#  ('Alesana', 'https://en.wikipedia.org/wiki/Alesana'),
#  ('Alexisonfire', 'https://en.wikipedia.org/wiki/Alexisonfire'),
#  ('Alkaline Trio', 'https://en.wikipedia.org/wiki/Alkaline_Trio'),
#  ('The All-American Rejects',
#   'https://en.wikipedia.org/wiki/The_All-American_Rejects'),
#  ('All Time Low', 'https://en.wikipedia.org/wiki/All_Time_Low'),
#  ('The Almost', 'https://en.wikipedia.org/wiki/The_Almost'),
#  ('Amber Pacific', 'https://en.wikipedia.org/wiki/Amber_Pacific'),
#  ('American Football',
#   'https://en.wikipedia.org/wiki/American_Football_(band)'),
#  ('Anberlin', 'https://en.wikipedia.org/wiki/Anberlin'),
#  ('And Then There Were None',
#   'https://en.wikipedia.org/wiki/And_Then_There_Were_None_(band)'),
#  ('...And You Will Know Us by the Trail of Dead',
#   'https://en.wikipedia.org/wiki/...And_You_Will_Know_Us_by_the_Trail_of_Dead'),
#  ('The Anniversary', 'https://en.wikipedia.org/wiki/The_Anniversary'),
#  ('The Appleseed Cast', 'https://en.wikipedia.org/wiki/The_Appleseed_Cast'),
#  ('Armor for Sleep', 'https://en.wikipedia.org/wiki/Armor_for_Sleep'),
#  ('As Cities Burn', 'https://en.wikipedia.org/wiki/As_Cities_Burn'),
#  ('At the Drive-In', 'https://en.wikipedia.org/wiki/At_the_Drive-In'),
#  ('August is Falling', 'https://en.wikipedia.org/wiki/August_is_Falling'),
#  ('Avion Roe', 'https://en.wikipedia.org/wiki/Avion_Roe'),
#  ('Bayside', 'https://en.wikipedia.org/wiki/Bayside_(band)'),
#  ('Beefeater', 'https://en.wikipedia.org/wiki/Beefeater_(band)'),
#  ('Before Their Eyes', 'https://en.wikipedia.org/wiki/Before_Their_Eyes'),
#  ('Beloved', 'https://en.wikipedia.org/wiki/Beloved_(band)'),
#  ('Benton Falls', 'https://en.wikipedia.org/wiki/Benton_Falls'),
#  ('Black Veil Brides', 'https://en.wikipedia.org/wiki/Black_Veil_Brides'),
#  ('Boys Like Girls', 'https://en.wikipedia.org/wiki/Boys_Like_Girls'),
#  ('Boys Night Out', 'https://en.wikipedia.org/wiki/Boys_Night_Out_(band)'),
#  ('Braid', 'https://en.wikipedia.org/wiki/Braid_(band)'),
#  ('Brand New', 'https://en.wikipedia.org/wiki/Brand_New_(band)'),
#  ('The Brave Little Abacus',
#   'https://en.wikipedia.org/wiki/The_Brave_Little_Abacus'),
#  ('Bring Me the Horizon',
#   'https://en.wikipedia.org/wiki/Bring_Me_the_Horizon'),
#  ('The Cab', 'https://en.wikipedia.org/wiki/The_Cab'),
#  ('Capital Lights', 'https://en.wikipedia.org/wiki/Capital_Lights'),
#  ("Cap'n Jazz", 'https://en.wikipedia.org/wiki/Cap%27n_Jazz'),
#  ('Chamberlain', 'https://en.wikipedia.org/wiki/Chamberlain_(band)'),
#  ('Chasing Victory', 'https://en.wikipedia.org/wiki/Chasing_Victory'),
#  ('Christie Front Drive',
#   'https://en.wikipedia.org/wiki/Christie_Front_Drive'),
#  ('City of Caterpillar', 'https://en.wikipedia.org/wiki/City_of_Caterpillar'),
#  ('The Classic Crime', 'https://en.wikipedia.org/wiki/The_Classic_Crime'),
#  ('Cobra Starship', 'https://en.wikipedia.org/wiki/Cobra_Starship'),
#  ('Coheed and Cambria', 'https://en.wikipedia.org/wiki/Coheed_and_Cambria'),
#  ('Cute Is What We Aim For',
#   'https://en.wikipedia.org/wiki/Cute_Is_What_We_Aim_For'),
#  ('Dads', 'https://en.wikipedia.org/wiki/Dads_(band)'),
#  ('Dag Nasty', 'https://en.wikipedia.org/wiki/Dag_Nasty'),
#  ('Dashboard Confessional',
#   'https://en.wikipedia.org/wiki/Dashboard_Confessional'),
#  ('A Day to Remember', 'https://en.wikipedia.org/wiki/A_Day_to_Remember'),
#  ('Dead Poetic', 'https://en.wikipedia.org/wiki/Dead_Poetic'),
#  ('Dear Ephesus', 'https://en.wikipedia.org/wiki/Dear_Ephesus'),
#  ('Death Cab for Cutie', 'https://en.wikipedia.org/wiki/Death_Cab_for_Cutie'),
#  ('The Dismemberment Plan',
#   'https://en.wikipedia.org/wiki/The_Dismemberment_Plan'),
#  ('Dizmas', 'https://en.wikipedia.org/wiki/Dizmas'),
#  ('Drive Like Jehu', 'https://en.wikipedia.org/wiki/Drive_Like_Jehu'),
#  ('Edison Glass', 'https://en.wikipedia.org/wiki/Edison_Glass'),
#  ('Eisley', 'https://en.wikipedia.org/wiki/Eisley'),
#  ('Elliott', 'https://en.wikipedia.org/wiki/Elliott_(band)'),
#  ('Emanuel', 'https://en.wikipedia.org/wiki/Emanuel_(band)'),
#  ('Embrace', 'https://en.wikipedia.org/wiki/Embrace_(American_band)'),
#  ('Emery', 'https://en.wikipedia.org/wiki/Emery_(band)'),
#  ('Empire! Empire! (I Was a Lonely Estate)',
#   'https://en.wikipedia.org/wiki/Empire!_Empire!_(I_Was_a_Lonely_Estate)'),
#  ('Escape the Fate', 'https://en.wikipedia.org/wiki/Escape_the_Fate'),
#  ('Ever Stays Red', 'https://en.wikipedia.org/wiki/Ever_Stays_Red'),
#  ('Every Avenue', 'https://en.wikipedia.org/wiki/Every_Avenue'),
#  ('Eyes Set to Kill', 'https://en.wikipedia.org/wiki/Eyes_Set_to_Kill'),
#  ('Fall Out Boy', 'https://en.wikipedia.org/wiki/Fall_Out_Boy'),
#  ('Falling in Reverse', 'https://en.wikipedia.org/wiki/Falling_in_Reverse'),
#  ('Falling Up', 'https://en.wikipedia.org/wiki/Falling_Up_(band)'),
#  ('Family Force 5', 'https://en.wikipedia.org/wiki/Family_Force_5'),
#  ('Farewell, My Love',
#   'https://en.wikipedia.org/wiki/Farewell,_My_Love_(Band)'),
#  ('Finch', 'https://en.wikipedia.org/wiki/Finch_(U.S._band)'),
#  ('Fire Party', 'https://en.wikipedia.org/wiki/Fire_Party'),
#  ('Fireflight', 'https://en.wikipedia.org/wiki/Fireflight'),
#  ('Flyleaf', 'https://en.wikipedia.org/wiki/Flyleaf_(band)'),
#  ('The Fold', 'https://en.wikipedia.org/wiki/The_Fold'),
#  ('Forever Changed', 'https://en.wikipedia.org/wiki/Forever_Changed'),
#  ('Forever the Sickest Kids',
#   'https://en.wikipedia.org/wiki/Forever_the_Sickest_Kids'),
#  ('Foxing', 'https://en.wikipedia.org/wiki/Foxing_(band)'),
#  ('Fragile Rock', 'https://en.wikipedia.org/wiki/Fragile_Rock'),
#  ('The Fray', 'https://en.wikipedia.org/wiki/The_Fray'),
#  ('From Autumn to Ashes',
#   'https://en.wikipedia.org/wiki/From_Autumn_to_Ashes'),
#  ('From First to Last', 'https://en.wikipedia.org/wiki/From_First_to_Last'),
#  ('Funeral for a Friend',
#   'https://en.wikipedia.org/wiki/Funeral_for_a_Friend'),
#  ('Further Seems Forever',
#   'https://en.wikipedia.org/wiki/Further_Seems_Forever'),
#  ('Garden Variety', 'https://en.wikipedia.org/wiki/Garden_Variety'),
#  ('The Get Up Kids', 'https://en.wikipedia.org/wiki/The_Get_Up_Kids'),
#  ('Gray Matter', 'https://en.wikipedia.org/wiki/Gray_Matter_(band)'),
#  ('Gwen Stacy', 'https://en.wikipedia.org/wiki/Gwen_Stacy_(band)'),
#  ('Haste the Day', 'https://en.wikipedia.org/wiki/Haste_the_Day'),
#  ('Hawk Nelson', 'https://en.wikipedia.org/wiki/Hawk_Nelson'),
#  ('Hawthorne Heights', 'https://en.wikipedia.org/wiki/Hawthorne_Heights'),
#  ('He Is Legend', 'https://en.wikipedia.org/wiki/He_Is_Legend'),
#  ('Hellogoodbye', 'https://en.wikipedia.org/wiki/Hellogoodbye'),
#  ('Hey Mercedes', 'https://en.wikipedia.org/wiki/Hey_Mercedes'),
#  ('Hey Monday', 'https://en.wikipedia.org/wiki/Hey_Monday'),
#  ('The Higher', 'https://en.wikipedia.org/wiki/The_Higher'),
#  ('Hoover', 'https://en.wikipedia.org/wiki/Hoover_(band)'),
#  ('Hot Rod Circuit', 'https://en.wikipedia.org/wiki/Hot_Rod_Circuit'),
#  ('The Hotelier', 'https://en.wikipedia.org/wiki/The_Hotelier'),
#  ('House of Heroes', 'https://en.wikipedia.org/wiki/House_of_Heroes'),
#  ('I Am Ghost', 'https://en.wikipedia.org/wiki/I_Am_Ghost'),
#  ('Ida', 'https://en.wikipedia.org/wiki/Ida_(band)'),
#  ('Indian Summer',
#   'https://en.wikipedia.org/wiki/Indian_Summer_(American_band)'),
#  ('Ivoryline', 'https://en.wikipedia.org/wiki/Ivoryline'),
#  ('Jawbreaker', 'https://en.wikipedia.org/wiki/Jawbreaker_(band)'),
#  ('Jets to Brazil', 'https://en.wikipedia.org/wiki/Jets_to_Brazil'),
#  ('Jetty Bones', 'https://en.wikipedia.org/wiki/Jetty_Bones'),
#  ('Jimmy Eat World', 'https://en.wikipedia.org/wiki/Jimmy_Eat_World'),
#  ('Joan of Arc', 'https://en.wikipedia.org/wiki/Joan_of_Arc_(band)'),
#  ('The Juliana Theory', 'https://en.wikipedia.org/wiki/The_Juliana_Theory'),
#  ('The Junior Varsity', 'https://en.wikipedia.org/wiki/The_Junior_Varsity'),
#  ('Karate', 'https://en.wikipedia.org/wiki/Karate_(band)'),
#  ('Kids in the Way', 'https://en.wikipedia.org/wiki/Kids_in_the_Way'),
#  ('Kiros', 'https://en.wikipedia.org/wiki/Kiros_(band)'),
#  ('Knapsack', 'https://en.wikipedia.org/wiki/Knapsack_(band)'),
#  ('Kutless', 'https://en.wikipedia.org/wiki/Kutless'),
#  ('Letter Kills', 'https://en.wikipedia.org/wiki/Letter_Kills'),
#  ('Life in Your Way', 'https://en.wikipedia.org/wiki/Life_in_Your_Way'),
#  ('Lifetime', 'https://en.wikipedia.org/wiki/Lifetime_(band)'),
#  ('Lostprophets', 'https://en.wikipedia.org/wiki/Lostprophets'),
#  ('Mae', 'https://en.wikipedia.org/wiki/Mae'),
#  ('Matchbook Romance', 'https://en.wikipedia.org/wiki/Matchbook_Romance'),
#  ('Mayday Parade', 'https://en.wikipedia.org/wiki/Mayday_Parade'),
#  ('Metro Station', 'https://en.wikipedia.org/wiki/Metro_Station_(band)'),
#  ('Krystal Meyers', 'https://en.wikipedia.org/wiki/Krystal_Meyers'),
#  ('Mineral', 'https://en.wikipedia.org/wiki/Mineral_(band)'),
#  ('Modern Baseball', 'https://en.wikipedia.org/wiki/Modern_Baseball'),
#  ('Mom Jeans', 'https://en.wikipedia.org/wiki/Mom_Jeans'),
#  ('Moneen', 'https://en.wikipedia.org/wiki/Moneen'),
#  ('Moose Blood', 'https://en.wikipedia.org/wiki/Moose_Blood'),
#  ('Moss Icon', 'https://en.wikipedia.org/wiki/Moss_Icon'),
#  ('The Movielife', 'https://en.wikipedia.org/wiki/The_Movielife'),
#  ('My Chemical Romance', 'https://en.wikipedia.org/wiki/My_Chemical_Romance'),
#  ('Native Nod', 'https://en.wikipedia.org/wiki/Native_Nod'),
#  ('New Found Glory', 'https://en.wikipedia.org/wiki/New_Found_Glory'),
#  ('Noise Ratchet', 'https://en.wikipedia.org/wiki/Noise_Ratchet'),
#  ('Northstar', 'https://en.wikipedia.org/wiki/Northstar_(band)'),
#  ('Nude', 'https://en.wikipedia.org/wiki/Nude_(band)'),
#  ('Number One Gun', 'https://en.wikipedia.org/wiki/Number_One_Gun'),
#  ('Once Nothing', 'https://en.wikipedia.org/wiki/Once_Nothing'),
#  ('Our Last Night', 'https://en.wikipedia.org/wiki/Our_Last_Night'),
#  ('Panic! at the Disco', 'https://en.wikipedia.org/wiki/Panic!_at_the_Disco'),
#  ('Paramore', 'https://en.wikipedia.org/wiki/Paramore'),
#  ('Pg. 99', 'https://en.wikipedia.org/wiki/Pg._99'),
#  ('Philmont', 'https://en.wikipedia.org/wiki/Philmont_(band)'),
#  ('Pierce the Veil', 'https://en.wikipedia.org/wiki/Pierce_the_Veil'),
#  ('Pillar', 'https://en.wikipedia.org/wiki/Pillar_(band)'),
#  ("Plain White T's", 'https://en.wikipedia.org/wiki/Plain_White_T%27s'),
#  ('Pop Unknown', 'https://en.wikipedia.org/wiki/Pop_Unknown'),
#  ('The Promise Ring', 'https://en.wikipedia.org/wiki/The_Promise_Ring'),
#  ('Punchline', 'https://en.wikipedia.org/wiki/Punchline_(band)'),
#  ('Rainer Maria', 'https://en.wikipedia.org/wiki/Rainer_Maria'),
#  ('The Red Jumpsuit Apparatus',
#   'https://en.wikipedia.org/wiki/The_Red_Jumpsuit_Apparatus'),
#  ('Rites of Spring', 'https://en.wikipedia.org/wiki/Rites_of_Spring'),
#  ('Roses Are Red', 'https://en.wikipedia.org/wiki/Roses_Are_Red_(band)'),
#  ('Rye Coalition', 'https://en.wikipedia.org/wiki/Rye_Coalition'),
#  ('Saetia', 'https://en.wikipedia.org/wiki/Saetia'),
#  ('Samiam', 'https://en.wikipedia.org/wiki/Samiam'),
#  ('Saosin', 'https://en.wikipedia.org/wiki/Saosin'),
#  ('Saves the Day', 'https://en.wikipedia.org/wiki/Saves_the_Day'),
#  ('Say Anything', 'https://en.wikipedia.org/wiki/Say_Anything_(band)'),
#  ('Secondhand Serenade', 'https://en.wikipedia.org/wiki/Secondhand_Serenade'),
#  ('Secret and Whisper', 'https://en.wikipedia.org/wiki/Secret_and_Whisper'),
#  ('Senses Fail', 'https://en.wikipedia.org/wiki/Senses_Fail'),
#  ('Sherwood', 'https://en.wikipedia.org/wiki/Sherwood_(band)'),
#  ('Showbread', 'https://en.wikipedia.org/wiki/Showbread_(band)'),
#  ('Silverstein', 'https://en.wikipedia.org/wiki/Silverstein_(band)'),
#  ('Simple Plan', 'https://en.wikipedia.org/wiki/Simple_Plan'),
#  ('Small Brown Bike', 'https://en.wikipedia.org/wiki/Small_Brown_Bike'),
#  ('Sleeping with Sirens',
#   'https://en.wikipedia.org/wiki/Sleeping_with_Sirens'),
#  ('Something Corporate', 'https://en.wikipedia.org/wiki/Something_Corporate'),
#  ('Spanish Love Songs', 'https://en.wikipedia.org/wiki/Spanish_Love_Songs'),
#  ('The Spill Canvas', 'https://en.wikipedia.org/wiki/The_Spill_Canvas'),
#  ('Split Lip', 'https://en.wikipedia.org/wiki/Split_Lip'),
#  ('Squirrel Bait', 'https://en.wikipedia.org/wiki/Squirrel_Bait'),
#  ('Static Dress', 'https://en.wikipedia.org/wiki/Static_Dress'),
#  ('The Starting Line', 'https://en.wikipedia.org/wiki/The_Starting_Line'),
#  ('Stavesacre', 'https://en.wikipedia.org/wiki/Stavesacre'),
#  ('Story of the Year', 'https://en.wikipedia.org/wiki/Story_of_the_Year'),
#  ('Sum 41', 'https://en.wikipedia.org/wiki/Sum_41'),
#  ('Sunny Day Real Estate',
#   'https://en.wikipedia.org/wiki/Sunny_Day_Real_Estate'),
#  ('Taking Back Sunday', 'https://en.wikipedia.org/wiki/Taking_Back_Sunday'),
#  ('Ten Second Epic', 'https://en.wikipedia.org/wiki/Ten_Second_Epic'),
#  ('Texas Is the Reason', 'https://en.wikipedia.org/wiki/Texas_Is_the_Reason'),
#  ('There for Tomorrow', 'https://en.wikipedia.org/wiki/There_for_Tomorrow'),
#  ('Thirty Seconds to Mars',
#   'https://en.wikipedia.org/wiki/Thirty_Seconds_to_Mars'),
#  ('This Beautiful Republic',
#   'https://en.wikipedia.org/wiki/This_Beautiful_Republic'),
#  ('This Providence', 'https://en.wikipedia.org/wiki/This_Providence'),
#  ('Twenty One Pilots', 'https://en.wikipedia.org/wiki/Twenty_One_Pilots'),
#  ('Thrice', 'https://en.wikipedia.org/wiki/Thrice'),
#  ('Thursday', 'https://en.wikipedia.org/wiki/Thursday_(band)'),
#  ('Tokio Hotel', 'https://en.wikipedia.org/wiki/Tokio_Hotel'),
#  ('Typecast', 'https://en.wikipedia.org/wiki/Typecast_(band)'),
#  ('Underoath', 'https://en.wikipedia.org/wiki/Underoath'),
#  ('The Used', 'https://en.wikipedia.org/wiki/The_Used'),
#  ('The Van Pelt', 'https://en.wikipedia.org/wiki/The_Van_Pelt'),
#  ('Watashi Wa', 'https://en.wikipedia.org/wiki/Watashi_Wa'),
#  ('The Wedding', 'https://en.wikipedia.org/wiki/The_Wedding_(band)'),
#  ('You, Me, and Everyone We Know',
#   'https://en.wikipedia.org/wiki/You,_Me,_and_Everyone_We_Know'),
#  ('Greenwald, Andy', 'https://en.wikipedia.org/wiki/Andy_Greenwald'),
#  ('Emo pop', 'https://en.wikipedia.org/wiki/Emo_pop'),
#  ('Midwest emo', 'https://en.wikipedia.org/wiki/Midwest_emo'),
#  ('Screamo', 'https://en.wikipedia.org/wiki/Screamo'),
#  ('Emo rap', 'https://en.wikipedia.org/wiki/Emo_rap'),
#  ('Emo revival', 'https://en.wikipedia.org/wiki/Emo_revival'),
#  ('Midwestern United States', 'https://en.wikipedia.org/wiki/Midwest_emo'),
#  ('Washington, D.C.',
#   'https://en.wikipedia.org/wiki/Music_of_Washington,_D.C.#Emo'),
#  ('New Jersey', 'https://en.wikipedia.org/wiki/Music_of_New_Jersey'),
#  ('Eesti',
#   'https://en.wikipedia.orghttps://et.wikipedia.org/wiki/Emoansamblite_loend'),
#  ('Bahasa Melayu',
#   'https://en.wikipedia.orghttps://ms.wikipedia.org/wiki/Senarai_artis_emo'),
#  ('Slovenščina',
#   'https://en.wikipedia.orghttps://sl.wikipedia.org/wiki/Seznam_emo_skupin')]

# %% [markdown]
# <p><span style="color:blue">get_all_musician_docs</span>: A function that, given the list of (musician,url) pairs, returns two lists, a list of musicians and a parallel (same size) list of documents.
#
# <p>You need to:
#
# <ol>
# <li>initialize the two lists
#
# <li>iterate through the all_musicians list
# <li>extract the name and the url of the musician
# <li>get the text using the get_musician_text() function
# <li>if the function returns None, ignore it and move to the next musician
# <li>otherwise, append the name ot the musician_names list and the text to the musician_texts list
# <li>return musician_names and musician_texts

# %%
def get_all_musician_docs(all_musicians):
    musician_names = list()
    musician_texts = list()
    for musician in all_musicians:
        name = musician[0]
        url = musician[1]
        if get_musician_text(url) is not None:
            musician_names.append(name)
            musician_texts.append(get_musician_text(url))
        else:
            continue
    return musician_names,musician_texts

# %% [markdown]
# <h4>Example of how to use get_all_musician_docs</h4>

# %%
reference_names,reference_docs = get_all_musician_docs(all_musicians)

# %%
reference_names
# Out:
# ['Tom Adams',
#  'Eddie Adcock',
#  'David "Stringbean" Akeman',
#  'Red Allen',
#  'Darol Anger',
#  'Mike Auldridge',
#  'Kenny Baker',
#  'Jessie Baker',
#  'Butch Baldassari',
#  'Russ Barenberg',
#  'Byron Berline',
#  'Carroll Best',
#  'Norman Blake',
#  'Kathy Boyd',
#  'Dale Ann Bradley',
#  'David Bromberg',
#  'Herman Brock Jr',
#  'Jesse Brock',
#  'Alison Brown',
#  'Buckethead',
#  'Buzz Busby',
#  'Roger Bush',
#  'Sam Bush',
#  'Ann Marie Calhoun',
#  'Jason Carter',
#  'Vassar Clements',
#  'Michael Cleveland',
#  'Bill Clifton',
#  'Charlie Cline',
#  'Curly Ray Cline',
#  'Mike Compton',
#  'John Byrne Cooke',
#  'J. P. Cormier',
#  'John Cowan',
#  'Dan Crary',
#  'J. D. Crowe',
#  'Jamie Dailey',
#  'Charlie Daniels',
#  'Vernon Derrick',
#  'Hazel Dickens',
#  'Doug Dillard',
#  'The Dillards',
#  'Jerry Douglas',
#  'Casey Driessen',
#  'John Duffey',
#  'Stuart Duncan',
#  'Chris Eldridge',
#  'Bill Emerson',
#  'Bill Evans',
#  'Lester Flatt',
#  'Dennis Fetchet',
#  'Pete Fidler',
#  'Béla Fleck',
#  'Sally Ann Forrester',
#  'Tony Furtado',
#  'Raymond Fairchild',
#  'Jerry Garcia',
#  'Josh Graves',
#  'Vince Gill',
#  'Brennan Gilmore',
#  'Johnny Gimble',
#  'Rhiannon Giddens',
#  'Richard Greene',
#  'Clinton Gregory',
#  'David Grier',
#  'Andy Griffith',
#  'David Grisman',
#  'Jamie Hartford',
#  'John Hartford',
#  'Aubrey Haynie',
#  'John Herald',
#  'Bobby Hicks',
#  'Chris Hillman',
#  'Scott Holstein',
#  'Sierra Hull',
#  'Rob Ickes',
#  'IIIrd Tyme Out',
#  'Jana Jae',
#  'Sarah Jarosz',
#  'Mitchell F. Jayne',
#  'Michael Kang',
#  'Kaia Kater',
#  'Larry Keel',
#  'Leslie Keith',
#  'Irene Kelley',
#  'Danny Knicely',
#  'Kenny Kosek',
#  'Alison Krauss',
#  'Gundula Krause',
#  'Robert Křesťan',
#  'Shawn Lane',
#  'Jim Lauderdale',
#  'Bernie Leadon',
#  'Doyle Lawson',
#  'Kate Lee',
#  'Ray Legere',
#  'Laurie Lewis',
#  'Benjamin F. Logan',
#  'Patty Loveless',
#  'Andy Leftwich',
#  'Claire Lynch',
#  'Mack Magaha',
#  'Benny Martin',
#  'Jimmy Martin',
#  'Mac Martin',
#  'Steve Martin',
#  'Bessie Lee Mauldin',
#  'Del McCoury',
#  'Jesse McReynolds',
#  'Jim McReynolds',
#  'Edgar Meyer',
#  'Charlie Monroe',
#  'Bill Monroe',
#  'Marcus Mumford',
#  'Alan Munde',
#  'Penny Nichols',
#  'Alecia Nugent',
#  "Tim O'Brien",
#  "Mark O'Connor",
#  'Dolly Parton',
#  'Todd Phillips',
#  'Danny Paisley',
#  'Missy Raines',
#  'Tommy Ramone',
#  'David Rawlings',
#  'Don Reno',
#  'Tony Rice',
#  'Alwyn Robinson',
#  'Peter Rowan',
#  'Gary Ruley',
#  'Josh Shilling',
#  'Earl Scruggs',
#  'Ricky Skaggs',
#  'Arthur Lee "Red" Smiley',
#  'Arthur "Guitar Boogie" Smith',
#  'Ruby Jane Smith',
#  'Johnny Staats',
#  'Carter Stanley',
#  'Ralph Stanley',
#  'Chris Stapleton',
#  'Andy Statman',
#  'Larry Stephenson',
#  'Billy Strings',
#  'Marty Stuart',
#  'Eddie Stubbs',
#  'Bryan Sutton',
#  'Gordon Terry',
#  'Chris Thile',
#  'Tony Trischka',
#  'Josh Turner',
#  'Molly Tuttle',
#  'Dan Tyminski',
#  'Donna Ulisse',
#  'Jim Van Cleve',
#  'Dailey & Vincent',
#  'Rhonda Vincent',
#  'Charlie Waller',
#  'Sara Watkins',
#  'Doc Watson',
#  'Eric Weissberg',
#  'Dean Webb',
#  'Gillian Welch',
#  'Clarence White',
#  'Roland White',
#  'Keith Whitley',
#  'Benny Williams',
#  '"Big" Paul Williams',
#  'Vern Williams',
#  'Chubby Wise',
#  'Mac Wiseman',
#  'Buddy Woodward',
#  'Gene Wooten',
#  'Rex Yetman',
#  'Bluegrass music',
#  'Country music',
#  'Guitar',
#  'acoustic',
#  'resonator',
#  'Banjo',
#  'Double bass',
#  'Fiddle',
#  'technique',
#  'Mandolin',
#  'resonator',
#  'technique',
#  'Blues',
#  'Country music',
#  'Jazz',
#  'Old-time music',
#  'Traditional bluegrass',
#  'Czech bluegrass',
#  'High Sierra Music Festival',
#  'Festival of the Bluegrass',
#  'Merlefest',
#  'Podunk Bluegrass Festival',
#  'Telluride Bluegrass Festival',
#  'Tottenham Bluegrass Festival',
#  'International Bluegrass Music Museum',
#  'International Bluegrass Music Association',
#  'International Bluegrass Music Hall of Fame',
#  'Bluegrass Unlimited',
#  'Central Canadian Bluegrass Awards',
#  'International Bluegrass Music Awards',
#  'Ian A. Anderson',
#  'Elles Bailey',
#  'Ginger Baker',
#  'Long John Baldry',
#  'Chris Barber',
#  'Norman Beaker',
#  'Jeff Beck',
#  'Duster Bennett',
#  'Graham Bond',
#  'Marcus Bonfanti',
#  'John Bonham',
#  'Geoff Bradford',
#  'Jack Broadbent',
#  'Jack Bruce',
#  'Danny Bryant',
#  'Eric Burdon',
#  'Eric Clapton',
#  'Joe Cocker',
#  'Mike Cooper',
#  'Cyril Davies',
#  'John Dummer',
#  'Aynsley Dunbar',
#  'Chris Farlowe',
#  'Mick Fleetwood',
#  'Peter Green',
#  'Nicky Hopkins',
#  'Mick Jagger',
#  'Brian Jones',
#  'Laurence Jones',
#  'Paul Jones',
#  'Wizz Jones',
#  'Jo Ann Kelly',
#  'Dave Kelly',
#  'Danny Kirwan',
#  'Alexis Korner',
#  'Paul Kossoff',
#  'Hugh Laurie',
#  'Alvin Lee',
#  'Bernie Marsden',
#  'John Mayall',
#  'Chantel McGregor',
#  'Scott McKeon',
#  'Tony McPhee',
#  'Christine McVie',
#  'John McVie',
#  'Micky Moody',
#  'Gary Moore',
#  'Billy Nicholls',
#  'Jimmy Page',
#  'Robert Palmer',
#  'Ottilie Patterson',
#  'Ben Poole',
#  'Duffy Power',
#  'Rod Price',
#  'Chris Rea',
#  'Keith Relf',
#  'Keith Richards',
#  'Paul Rodgers',
#  'Matt Schofield',
#  'Todd Sharpville',
#  'Innes Sibun',
#  'Kim Simmonds',
#  'Jeremy Spencer',
#  'Chris Stainton',
#  'Rod Stewart',
#  'Mick Taylor',
#  'Joanne Shaw Taylor',
#  'Top Topham',
#  'Snowy White',
#  'Dani Wilde',
#  'The Animals',
#  'Back Door Slam',
#  'The Birds',
#  'Black Cat Bones',
#  'The Blues Band',
#  'Blues Incorporated',
#  'Bluesology',
#  'Chicken Shack',
#  'Climax Blues Band',
#  'Cream',
#  'Downliners Sect',
#  'Dr. Feelgood',
#  'Fleetwood Mac',
#  'Foghat',
#  'Free',
#  'The Groundhogs',
#  'The Hamsters',
#  'Jeff Beck Group',
#  'The Jimi Hendrix Experience',
#  'John Mayall & the Bluesbreakers',
#  'Juicy Lucy',
#  'Keef Hartley Band',
#  'King King',
#  'Led Zeppelin',
#  'Love Sculpture',
#  'Manfred Mann',
#  'Medicine Head',
#  'The Original Rabbit Foot Spasm Band',
#  'Peter Green Splinter Group',
#  'The Poets',
#  'The Pretty Things',
#  'The Rolling Stones',
#  'Savoy Brown',
#  'Spencer Davis Group',
#  'Starlite Campbell Band',
#  'Steamhammer',
#  'The Steampacket',
#  'Taste',
#  'Ten Years After',
#  'Them',
#  'Tramp',
#  'Twice as Much',
#  'The Yardbirds',
#  'When Rivers Meet',
#  'Whitesnake',
#  'Wishbone Ash',
#  'Blues ballad',
#  'Blue note',
#  'Blues scale',
#  'Call and response',
#  'Eight-bar blues',
#  'Musical improvisation',
#  'Shuffles',
#  'Traditional blues verses',
#  'Twelve-bar blues',
#  'Walking bass',
#  'Origins',
#  'Field hollers',
#  'Spirituals',
#  'Work songs',
#  'American folk music',
#  'African blues',
#  'Anatolian blues',
#  'British blues',
#  'Canadian blues',
#  'Chicago blues',
#  'Delta blues',
#  'Hill country blues',
#  'Indian blues',
#  'Louisiana blues',
#  'New Orleans blues',
#  'Swamp blues',
#  'Memphis blues',
#  'Piedmont blues',
#  'Texas blues',
#  'West Coast blues',
#  'Boogie-woogie',
#  'Classic female blues',
#  'Country blues',
#  'Dirty blues',
#  'Electric blues',
#  'Fife and drum blues',
#  'Hokum',
#  'Jug band',
#  'Rhythm and blues',
#  'Blues rock',
#  'Gospel blues',
#  'Jump blues',
#  'Southern rock',
#  'Alger "Texas" Alexander',
#  'Pink Anderson',
#  'Howard "Louie Bluie" Armstrong',
#  'Backwards Sam Firk',
#  'DeFord Bailey',
#  'Etta Baker',
#  'Barbecue Bob',
#  'John Henry Barbee',
#  'Robert Belfour',
#  'Ed Bell',
#  'Scrapper Blackwell',
#  'Blind Blake',
#  'Lucille Bogan',
#  'Ted Bogan',
#  'Bogus Ben Covington',
#  'Son Bonds',
#  'Ishmon Bracey',
#  'Big Bill Broonzy',
#  'Bob Brozman',
#  'Bumble Bee Slim',
#  'R.L. Burnside',
#  'Butterbeans and Susie',
#  'Mississippi Joe Callicott',
#  "Cannon's Jug Stompers",
#  'Bo Carter',
#  'John Cephas',
#  'Jaybird Coleman',
#  'Floyd Council',
#  'Ida Cox',
#  'James Crutchfield',
#  'Reverend Gary Davis',
#  'Little Buddy Doyle',
#  'Sleepy John Estes',
#  'Blind Boy Fuller',
#  'Jesse Fuller',
#  'Terry Garland',
#  'Jazz Gillum',
#  'Ramon Goose',
#  'Coot Grant',
#  'William Harris',
#  'Richard "Hacksaw" Harney',
#  'Hattie Hart',
#  'Buddy Boy Hawkins',
#  'Jessie Mae Hemphill',
#  "Lightnin' Hopkins",
#  'Son House',
#  'Peg Leg Howell',
#  'Mississippi John Hurt',
#  'Melvin "Lil\' Son" Jackson',
#  'Papa Charlie Jackson',
#  'Skip James',
#  'Blind Lemon Jefferson',
#  'Herman E. Johnson',
#  'Lonnie Johnson',
#  'Robert Johnson',
#  'Blind Willie Johnson',
#  'Richard Johnston',
#  'Tutu Jones',
#  'Luke Jordan',
#  'Junior Kimbrough',
#  'Lottie Kimbrough',
#  'Lead Belly',
#  'John Lee',
#  'Furry Lewis',
#  'Noah Lewis',
#  'Charley Lincoln',
#  'Mance Lipscomb',
#  'Robert Lockwood, Jr.',
#  'John Long',
#  'Ida May Mack',
#  'Eddie Mapp',
#  'Carl Martin',
#  'Papa Charlie McCoy',
#  'Charlie "Specks" McFadden',
#  'Mississippi Fred McDowell',
#  'Brownie McGhee',
#  'Tommy McClennan',
#  'Blind Willie McTell',
#  'Memphis Jug Band',
#  'Memphis Minnie',
#  'The Mississippi Moaner',
#  'Mississippi Sheiks',
#  'Sonny Boy Nelson',
#  'Robert Nighthawk',
#  'Hammie Nixon',
#  'Charley Patton',
#  'Peg Leg Sam',
#  'Robert Petway',
#  'Reverend Peyton',
#  'Dan Pickett',
#  'Polka Dot Slim',
#  'Henry Qualls',
#  'Yank Rachell',
#  'Walter Roland',
#  'Doctor Ross',
#  'Carl Rutherford',
#  'Dan Sane',
#  'Irene Scruggs',
#  'Alec Seward',
#  'J.D. Short',
#  'Frankie Lee Sims',
#  'Laura Smith',
#  'Victoria Spivey',
#  'Frank Stokes',
#  'Tampa Red',
#  'Baby Tate',
#  'Sonny Terry',
#  'Henry Thomas',
#  "Ramblin' Thomas",
#  'Bessie Tucker',
#  'Sippie Wallace',
#  'Curley Weaver',
#  'Boogie Bill Webb',
#  'Peetie Wheatstraw',
#  'Bukka White',
#  'Big Joe Williams',
#  'Sonny Boy Williamson I',
#  'Sonny Boy Williamson II',
#  'Jontavious Willis',
#  'Ralph Willis',
#  'Wesley Wilson',
#  'Johnny Winter',
#  'The Academy Is...',
#  'Acceptance',
#  'Ace Troubleshooter',
#  'AFI',
#  'Aiden',
#  'Alesana',
#  'Alexisonfire',
#  'Alkaline Trio',
#  'The All-American Rejects',
#  'All Time Low',
#  'The Almost',
#  'Amber Pacific',
#  'American Football',
#  'Anberlin',
#  'And Then There Were None',
#  '...And You Will Know Us by the Trail of Dead',
#  'The Anniversary',
#  'The Appleseed Cast',
#  'Armor for Sleep',
#  'As Cities Burn',
#  'At the Drive-In',
#  'August is Falling',
#  'Avion Roe',
#  'Bayside',
#  'Beefeater',
#  'Before Their Eyes',
#  'Beloved',
#  'Benton Falls',
#  'Black Veil Brides',
#  'Boys Like Girls',
#  'Boys Night Out',
#  'Braid',
#  'Brand New',
#  'The Brave Little Abacus',
#  'Bring Me the Horizon',
#  'The Cab',
#  'Capital Lights',
#  "Cap'n Jazz",
#  'Chamberlain',
#  'Chasing Victory',
#  'Christie Front Drive',
#  'City of Caterpillar',
#  'The Classic Crime',
#  'Cobra Starship',
#  'Coheed and Cambria',
#  'Cute Is What We Aim For',
#  'Dads',
#  'Dag Nasty',
#  'Dashboard Confessional',
#  'A Day to Remember',
#  'Dead Poetic',
#  'Dear Ephesus',
#  'Death Cab for Cutie',
#  'The Dismemberment Plan',
#  'Dizmas',
#  'Drive Like Jehu',
#  'Edison Glass',
#  'Eisley',
#  'Elliott',
#  'Emanuel',
#  'Embrace',
#  'Emery',
#  'Empire! Empire! (I Was a Lonely Estate)',
#  'Escape the Fate',
#  'Ever Stays Red',
#  'Every Avenue',
#  'Eyes Set to Kill',
#  'Fall Out Boy',
#  'Falling in Reverse',
#  'Falling Up',
#  'Family Force 5',
#  'Farewell, My Love',
#  'Finch',
#  'Fire Party',
#  'Fireflight',
#  'Flyleaf',
#  'The Fold',
#  'Forever Changed',
#  'Forever the Sickest Kids',
#  'Foxing',
#  'Fragile Rock',
#  'The Fray',
#  'From Autumn to Ashes',
#  'From First to Last',
#  'Funeral for a Friend',
#  'Further Seems Forever',
#  'Garden Variety',
#  'The Get Up Kids',
#  'Gray Matter',
#  'Gwen Stacy',
#  'Haste the Day',
#  'Hawk Nelson',
#  'Hawthorne Heights',
#  'He Is Legend',
#  'Hellogoodbye',
#  'Hey Mercedes',
#  'Hey Monday',
#  'The Higher',
#  'Hoover',
#  'Hot Rod Circuit',
#  'The Hotelier',
#  'House of Heroes',
#  'I Am Ghost',
#  'Ida',
#  'Indian Summer',
#  'Ivoryline',
#  'Jawbreaker',
#  'Jets to Brazil',
#  'Jetty Bones',
#  'Jimmy Eat World',
#  'Joan of Arc',
#  'The Juliana Theory',
#  'The Junior Varsity',
#  'Karate',
#  'Kids in the Way',
#  'Kiros',
#  'Knapsack',
#  'Kutless',
#  'Letter Kills',
#  'Life in Your Way',
#  'Lifetime',
#  'Lostprophets',
#  'Mae',
#  'Matchbook Romance',
#  'Mayday Parade',
#  'Metro Station',
#  'Krystal Meyers',
#  'Mineral',
#  'Modern Baseball',
#  'Mom Jeans',
#  'Moneen',
#  'Moose Blood',
#  'Moss Icon',
#  'The Movielife',
#  'My Chemical Romance',
#  'Native Nod',
#  'New Found Glory',
#  'Noise Ratchet',
#  'Northstar',
#  'Nude',
#  'Number One Gun',
#  'Once Nothing',
#  'Our Last Night',
#  'Panic! at the Disco',
#  'Paramore',
#  'Pg. 99',
#  'Philmont',
#  'Pierce the Veil',
#  'Pillar',
#  "Plain White T's",
#  'Pop Unknown',
#  'The Promise Ring',
#  'Punchline',
#  'Rainer Maria',
#  'The Red Jumpsuit Apparatus',
#  'Rites of Spring',
#  'Roses Are Red',
#  'Rye Coalition',
#  'Saetia',
#  'Samiam',
#  'Saosin',
#  'Saves the Day',
#  'Say Anything',
#  'Secondhand Serenade',
#  'Secret and Whisper',
#  'Senses Fail',
#  'Sherwood',
#  'Showbread',
#  'Silverstein',
#  'Simple Plan',
#  'Small Brown Bike',
#  'Sleeping with Sirens',
#  'Something Corporate',
#  'Spanish Love Songs',
#  'The Spill Canvas',
#  'Split Lip',
#  'Squirrel Bait',
#  'Static Dress',
#  'The Starting Line',
#  'Stavesacre',
#  'Story of the Year',
#  'Sum 41',
#  'Sunny Day Real Estate',
#  'Taking Back Sunday',
#  'Ten Second Epic',
#  'Texas Is the Reason',
#  'There for Tomorrow',
#  'Thirty Seconds to Mars',
#  'This Beautiful Republic',
#  'This Providence',
#  'Twenty One Pilots',
#  'Thrice',
#  'Thursday',
#  'Tokio Hotel',
#  'Typecast',
#  'Underoath',
#  'The Used',
#  'The Van Pelt',
#  'Watashi Wa',
#  'The Wedding',
#  'You, Me, and Everyone We Know',
#  'Greenwald, Andy',
#  'Emo pop',
#  'Midwest emo',
#  'Screamo',
#  'Emo rap',
#  'Emo revival',
#  'Midwestern United States',
#  'Washington, D.C.',
#  'New Jersey']

# %% [raw]
# reference_docs

# %% [markdown]
# <h3>Set up the LSI model</h3>
# <li>reference_docs is the list of documents
# <li>construct texts, dictionary, and corpus (see class iPython notebook)
# <li>construct an LSI model. Use 5 topics initially but you should play around with this number

# %%
documents = reference_docs
texts = [[word for word in document.lower().split()
        if word not in STOPWORDS and word.isalnum()]
        for document in documents]
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=5)

# %% [markdown]
# <h3>Construct the "musician" data set</h3>
# <h4>Example</h4>

# %%
musician_genre_list = ['acid_rock_artists']
all_musicians = get_all_musicians(musician_genre_list)
musician_names,musician_docs = get_all_musician_docs(all_musicians)

# %% [markdown]
# <h4>find the most similar musicians for each new musician from our reference data set</h4>

# %%
table_data = list()
for i,musician in enumerate(musician_docs):
    vec_bow = dictionary.doc2bow(musician.lower().split())   
    vec_lsi = lsi[vec_bow] 
    index = similarities.MatrixSimilarity(lsi[corpus])
    sims = index[vec_lsi]
    sims = sorted(enumerate(sims), key=lambda item: -item[1])
    
    most_similar_musician = sims[0][0]
    table_data.append((musician_names[i],reference_names[most_similar_musician]))
    
table_data
# Out:
# [('The 13th Floor Elevators', 'Fragile Rock'),
#  ('Alice Cooper', 'At the Drive-In'),
#  ('The Amboy Dukes', 'Joan of Arc'),
#  ('Amon Düül', 'Joan of Arc'),
#  ('Big Brother and the Holding Company', 'The Pretty Things'),
#  ('Black Sabbath', 'Nude'),
#  ('Blue Cheer', 'Steamhammer'),
#  ('Blues Magoos', 'Hattie Hart'),
#  ('The Charlatans', 'Fire Party'),
#  ('Count Five', 'The Pretty Things'),
#  ('Country Joe and the Fish', 'Ray Legere'),
#  ('Coven', 'Marcus Mumford'),
#  ('Cream', 'Cream'),
#  ('Deep Purple', 'Nude'),
#  ('The Deviants', 'Braid'),
#  ('The Doors', 'The Pretty Things'),
#  ('The Electric Prunes', 'Joan of Arc'),
#  ('The Fugs', 'Free'),
#  ('Grateful Dead', 'Drive Like Jehu'),
#  ('The Great Society', 'Wishbone Ash'),
#  ('The Groundhogs', 'The Groundhogs'),
#  ('Hawkwind', 'Wishbone Ash'),
#  ('Iron Butterfly', 'Steamhammer'),
#  ('Jefferson Airplane', 'The Animals'),
#  ('The Jimi Hendrix Experience', 'The Jimi Hendrix Experience'),
#  ('Janis Joplin', 'Led Zeppelin'),
#  ('JPT Scare Band', 'Rites of Spring'),
#  ('Love', 'Them'),
#  ('MC5', 'Drive Like Jehu'),
#  ('Moby Grape', 'Billy Nicholls'),
#  ('The Music Machine', 'Ray Legere'),
#  ('Neil Young and Crazy Horse', 'Robert Palmer'),
#  ('Quicksilver Messenger Service', 'The Pretty Things'),
#  ('Santana', 'Whitesnake'),
#  ('The Seeds', 'The Pretty Things'),
#  ('Grace Slick', 'Red Allen'),
#  ('Steppenwolf', 'Foghat'),
#  ('Tully', 'Penny Nichols'),
#  ('Vanilla Fudge', 'Garden Variety'),
#  ('Wooden Shjips', 'Rob Ickes'),
#  ('Acid rock', 'Coot Grant'),
#  ('Knowles, Christopher', 'David "Stringbean" Akeman'),
#  ('McIntyre, Iain', 'Vassar Clements'),
#  ('Prown, Pete', 'Don Reno'),
#  ('Folk', 'Bill Monroe'),
#  ('New Weird America', 'American folk music'),
#  ('Funk', 'Emo revival'),
#  ('Pop', 'Merlefest'),
#  ('Rock', 'Dennis Fetchet'),
#  ('Soul', 'Ida May Mack'),
#  ('Trance', 'Laurie Lewis'),
#  ('House', 'Kenny Baker'),
#  ('Jazz', 'Jazz'),
#  ('Punk', 'Dennis Fetchet'),
#  ('Rock', 'Coot Grant'),
#  ('Techno', 'Fiddle'),
#  ('Trance', 'Central Canadian Bluegrass Awards'),
#  ('Chillwave', 'Bill Clifton'),
#  ('Dream-beat', 'Work songs'),
#  ('Freakbeat', 'Gordon Terry'),
#  ('Hypnagogic pop', 'Kenny Kosek'),
#  ('Italian occult psychedelia', 'International Bluegrass Music Museum'),
#  ('Krautrock', 'Old-time music'),
#  ('Madchester', 'Ruby Jane Smith'),
#  ('Neo-psychedelia', 'Dennis Fetchet'),
#  ('Dream pop', 'Ruby Jane Smith'),
#  ('Shoegaze', 'Béla Fleck'),
#  ('Paisley Underground', 'Dr. Feelgood'),
#  ('Sampledelia', 'Laurie Lewis'),
#  ('Space rock', 'Fragile Rock'),
#  ('Stoner rock', 'Manfred Mann'),
#  ('Tropicália', 'Howard "Louie Bluie" Armstrong'),
#  ('Zamrock', 'Work songs'),
#  ('Beat Generation', 'Mike Cooper'),
#  ('Cannabis culture', 'Midwest emo'),
#  ('Counterculture of the 1960s', 'Tony Furtado'),
#  ('Deadhead', 'Drive Like Jehu'),
#  ('Freak scene', 'Hammie Nixon'),
#  ('Grebo', 'J. D. Crowe'),
#  ('Hippies', 'Dennis Fetchet'),
#  ('Jam band', 'David Grisman'),
#  ('New Age travellers', 'Tony Furtado'),
#  ('Rave culture', 'Call and response'),
#  ('San Francisco sound', 'Tony Furtado'),
#  ('Second Summer of Love', 'Kenny Kosek'),
#  ('Summer of Love', 'Buzz Busby'),
#  ('UK underground', 'Gary Ruley'),
#  ('Palm Desert Scene', 'John Byrne Cooke'),
#  ('Psychedelia', 'Work songs')]

# %% [markdown]
# # Some simple sentiment analysis

# %% [markdown]
# In this part we are gonna run some simple sentiment analysis using the previously defined muscian_names and musician_docs lists.

# %% [markdown]
# Define a function simple_sentiment_analysis(musician_names,musician_docs) that takes as inputs the list of musician and their corresponding descriptions.
# The expected output is a list, each element of this list should be a list with the musician name, the percentage of positive words in his description and the percentage of negative words in his description.

# %%
#Example output
"""
[('The 13th Floor Elevators', 0.94, 1.16),
('Alice Cooper', 1.73, 1.34),
('The Amboy Dukes', 1.28, 1.01),
 ...]
"""

# %% [markdown]
# To ensure results can be compared please use the following function to define your list of positive and negative words:

# %%
def get_pos_neg_words():
    def get_words(url):
        import requests
        words = requests.get(url).content.decode('latin-1')
        word_list = words.split('\n')
        index = 0
        while index < len(word_list):
            word = word_list[index]
            if ';' in word or not word:
                word_list.pop(index)
            else:
                index+=1
        return word_list
    #Get lists of positive and negative words
    p_url = 'http://ptrckprry.com/course/ssd/data/positive-words.txt'
    n_url = 'http://ptrckprry.com/course/ssd/data/negative-words.txt'
    positive_words = get_words(p_url)
    negative_words = get_words(n_url)
    return positive_words,negative_words

# %%
def simple_sentiment_analysis(musician_names,musician_docs, debug=False):
    results=[]
    positive_words,negative_words = get_pos_neg_words()
    musician_data_list=list(zip(musician_names, musician_docs))
    from nltk import word_tokenize
    
    for text in musician_data_list:
        cpos=cneg=lpos=lneg=0
        for word in word_tokenize(text[1]):
            if word in positive_words:
                if debug:
                    print("Positive",word)
                cpos+=1
            if word in negative_words:
                if debug:
                    print("Negative",word)
                cneg+=1
        c_neg_score=round(((cneg/len(word_tokenize(text[1])))*100),2)
        c_pos_score=round(((cpos/len(word_tokenize(text[1])))*100),2)
        results.append((text[0],c_pos_score,c_neg_score))
    return results

# %%
simple_sentiment_analysis(musician_names,musician_docs)
# Out:
# [('The 13th Floor Elevators', 0.94, 1.16),
#  ('Alice Cooper', 1.73, 1.34),
#  ('The Amboy Dukes', 1.28, 1.01),
#  ('Amon Düül', 1.34, 1.05),
#  ('Big Brother and the Holding Company', 1.65, 0.74),
#  ('Black Sabbath', 1.31, 1.42),
#  ('Blue Cheer', 0.96, 1.05),
#  ('Blues Magoos', 1.15, 0.31),
#  ('The Charlatans', 0.83, 1.67),
#  ('Count Five', 1.07, 1.07),
#  ('Country Joe and the Fish', 1.54, 1.25),
#  ('Coven', 0.66, 0.66),
#  ('Cream', 1.54, 1.24),
#  ('Deep Purple', 1.31, 0.78),
#  ('The Deviants', 0.2, 0.61),
#  ('The Doors', 1.39, 1.36),
#  ('The Electric Prunes', 1.4, 1.06),
#  ('The Fugs', 0.51, 0.96),
#  ('Grateful Dead', 1.35, 0.71),
#  ('The Great Society', 0.89, 0.38),
#  ('The Groundhogs', 1.07, 0.68),
#  ('Hawkwind', 1.07, 0.86),
#  ('Iron Butterfly', 1.11, 1.34),
#  ('Jefferson Airplane', 1.53, 1.01),
#  ('The Jimi Hendrix Experience', 1.4, 1.13),
#  ('Janis Joplin', 1.27, 1.12),
#  ('JPT Scare Band', 0.79, 1.19),
#  ('Love', 1.56, 1.06),
#  ('MC5', 1.87, 1.64),
#  ('Moby Grape', 1.38, 1.14),
#  ('The Music Machine', 1.39, 1.55),
#  ('Neil Young and Crazy Horse', 1.3, 1.16),
#  ('Quicksilver Messenger Service', 1.61, 0.98),
#  ('Santana', 1.88, 0.94),
#  ('The Seeds', 1.37, 0.93),
#  ('Grace Slick', 1.21, 0.97),
#  ('Steppenwolf', 1.76, 0.91),
#  ('Tully', 1.93, 0.74),
#  ('Vanilla Fudge', 1.02, 0.62),
#  ('Wooden Shjips', 0.0, 0.0),
#  ('Acid rock', 1.06, 1.9),
#  ('Knowles, Christopher', 1.11, 0.37),
#  ('McIntyre, Iain', 0.8, 0.73),
#  ('Prown, Pete', 2.23, 0.37),
#  ('Folk', 1.66, 1.23),
#  ('New Weird America', 0.88, 0.35),
#  ('Funk', 1.06, 0.38),
#  ('Pop', 1.42, 1.71),
#  ('Rock', 1.42, 0.69),
#  ('Soul', 1.9, 0.51),
#  ('Trance', 1.9, 0.98),
#  ('House', 1.27, 1.16),
#  ('Jazz', 1.41, 0.63),
#  ('Punk', 1.5, 1.5),
#  ('Rock', 1.06, 1.9),
#  ('Techno', 0.32, 0.65),
#  ('Trance', 1.43, 0.29),
#  ('Chillwave', 1.93, 1.75),
#  ('Dream-beat', 1.75, 0.83),
#  ('Freakbeat', 0.35, 0.35),
#  ('Hypnagogic pop', 1.43, 1.78),
#  ('Italian occult psychedelia', 1.49, 1.79),
#  ('Krautrock', 1.41, 0.89),
#  ('Madchester', 1.75, 0.57),
#  ('Neo-psychedelia', 1.5, 1.5),
#  ('Dream pop', 2.0, 1.64),
#  ('Shoegaze', 1.42, 1.1),
#  ('Paisley Underground', 1.21, 0.75),
#  ('Sampledelia', 0.85, 1.17),
#  ('Space rock', 1.53, 0.89),
#  ('Stoner rock', 1.49, 1.34),
#  ('Tropicália', 1.57, 2.4),
#  ('Zamrock', 1.92, 2.61),
#  ('Beat Generation', 1.52, 1.25),
#  ('Cannabis culture', 1.53, 0.84),
#  ('Counterculture of the 1960s', 2.2, 1.83),
#  ('Deadhead', 1.97, 0.3),
#  ('Freak scene', 1.42, 3.03),
#  ('Grebo', 2.06, 1.65),
#  ('Hippies', 2.1, 1.12),
#  ('Jam band', 2.25, 1.74),
#  ('New Age travellers', 1.6, 1.07),
#  ('Rave culture', 1.46, 1.16),
#  ('San Francisco sound', 2.81, 0.65),
#  ('Second Summer of Love', 1.53, 0.97),
#  ('Summer of Love', 1.26, 0.67),
#  ('UK underground', 1.62, 1.85),
#  ('Palm Desert Scene', 1.61, 2.49),
#  ('Psychedelia', 3.06, 0.85)]
